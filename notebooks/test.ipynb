# %%
a = 10

# %%
b = 20

# %% [markdown]
# fjasdkljfa fjaksdlfjl;kas

# %%
print(a + b)
# Out:
# 30

# %%
a
b = 20

fjasdkljfa fjaksdlfjl;kas
print(a + b)
# Out:
#   Cell In[17], line 4
#     fjasdkljfa fjaksdlfjl;kas
#                ^
# SyntaxError: invalid syntax

# %%
# %%
a = 10

# %%
b = 20

# %%
print(a + b)
# Out:
# 30
